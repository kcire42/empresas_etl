# %%
import pandas as pd
from search_data import *
from pathlib import Path
from transformacion import *
from connect import *

# %%
directorio = Path('/Users/kcire/Google Drive/Mi unidad/Programacion/Python/Projects/empresa/Data')
database_name,path_name = define_database_info(get_path(directorio))
sheets = sheets_names(path_name)
data = create_df(path_name,sheets)

# %% [markdown]
# # Clientes

# %%
#hacer la transformacion de los datos 
clientes = data['CLIENTES']
clientes = drop_null(clientes)
clientes = uppercase(clientes)
clientes = remove_accents(clientes)
clientes
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#     NUMEROCLIENTE      NOMBRECLIENTE            DIRECCION       POBLACION  \
# 0               1   CABALLERO FLORES           ROSALES 78    AZCAPOTZALCO
# 1               2    ANCONA GONZALEZ      GOMEZ FARIAS 23  MIGUEL HIDALGO
# 2               3        AVALOS DIAZ          ALLENDE 432          TOLUCA
# 3               4       CRUZ MORALES            ESTEPA 67    VILLAHERMOSA
# 4               5        CORTES LUNA       MATUSALEN 4789        PROGRESO
# 5               6         DIAZ LOPEZ       PINO SUAREZ 78        ALVARADO
# 6               7       ESTRADA SOTO           TAMESIS 45         GUASAVE
# 7               8   FERNANDEZ GRACIA           RODANO 876       TAPACHULA
# ...

# %%
#cargar los datos en la base de datos
load_data(clientes,'empresa','clientes')
# Out:
# Loading data into empresa...
# Database 'empresa' does not exist, creating it...
# Database 'empresa' created successfully.
# ✅ Connection established
# 📤 Data loaded successfully into table clientes

# %% [markdown]
# # Region

# %%
#hacer la transformacion de los datos 
region = data['REGION']
region = drop_null(region)
region = uppercase(region)
region = remove_accents(region)
region.head()
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#    REGION NOMBREREGION  ACUMULADOREGION
# 0       1        BAJIO                0
# 1       2       CENTRO                0
# 2       3        GOLFO                0
# 3       4        NORTE                0
# 4       5     PACIFICO                0

# %%
#cargar los datos en la base de datos
load_data(region,'empresa','region')
# Out:
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table region

# %% [markdown]
# # Agentes

# %%
#hacer la transformacion de los datos 
agentes = data['AGENTES']
agentes = drop_null(agentes)
agentes = uppercase(agentes)
agentes = remove_accents(agentes)
agentes
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#     NUMEROAGENTE      NOMBREAGENTE FECHAALTAAGENTE  ACUMULADOAGENTE
# 0              1     CASTRO GARCIA      2010-11-12                0
# 1              2        DURAN CANO      2010-12-27                0
# 2              3    GALICIA PINEDA      2011-02-10                0
# 3              4       LOPEZ AVILA      2011-03-27                0
# 4              5       MORA SUAREZ      2011-05-11                0
# 5              6     PRADO MIRANDA      2011-06-25                0
# 6              7         RIOS ALVA      2011-12-09                0
# 7              8        RIVAS VACA      2012-05-25                0
# ...

# %%
#cargar los datos en la base de datos
load_data(agentes,'empresa','agentes')
# Out:
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table agentes

# %% [markdown]
# # Provedores

# %%
#hacer la transformacion de los datos 
provedores = data['PROVEEDORES']
provedores = drop_null(provedores)
provedores = uppercase(provedores)
provedores = remove_accents(provedores)
provedores
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#    NUMEROPROV                                  NOMBREPROV
# 0           1    GRUPO INDISTRIAL EN ALIMENTOS DE CALIDAD
# 1           2          PROVEEDORES DE ALIMENTOS DE CANCUN
# 2           3                 ALIMENTOS DE CONSUMO HUMANO
# 3           4                                ZETUS MEXICO
# 4           5                 GRUPO PROVEEDOR GASTRONOMIA
# 5           6                                       SIGMA
# 6           7            ALIMENTOS Y SERVICIOS INTEGRALES
# 7           8                                    PRODISET
# 8           9  EMPAQUES UNIVERSALES PARA ALIMENTOS FLORES
# 9          10                               ABASTO BASICO

# %%
#cargar los datos en la base de datos
load_data(provedores,'empresa','provedores')
# Out:
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table provedores

# %% [markdown]
# # Productos

# %%
productos = data['PRODUCTOS']
productos = drop_null(productos)
productos = uppercase(productos)
productos = remove_accents(productos)
productos
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#     CLAVEPROD    DESCRIPCIONPROD UNIDAD  EXISTENCIAS  COSTOUNITARIO  \
# 0           1         TALLARINES     KG          786             54
# 1           2               ANIS  LITRO         1098             56
# 2           3      AZUCAR MORENA     KG          225             32
# 3           4             MEZCAL  LITRO          879             56
# 4           5            CERVEZA  LITRO          287             87
# 5           6      LICOR DE NUEZ  LITRO          254             45
# 6           7            TEQUILA  LITRO          308             34
# 7           8             BRANDY  LITRO          256             89
# ...

# %%
#cargar los datos en la base de datos
load_data(productos,'empresa','productos')
# Out:
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table productos

# %% [markdown]
# # Factura

# %%
#hacer la transformacion de los datos 
factura = data['FACTURAS']
factura = drop_null(factura)
factura = uppercase(factura)
factura = remove_accents(factura)
factura
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#       NUMEROFACT  FECHAFACT  NUMEROCLIENTE  NUMEROAGENTE  SUBTOTALFACT  \
# 0              1 2012-01-02             18            11          7638
# 1              2 2012-01-02              8             2          7058
# 2              3 2012-01-03             19            17          4418
# 3              4 2012-01-03              9            12          8294
# 4              5 2012-01-04              5             9          1300
# ...          ...        ...            ...           ...           ...
# 1995        1996 2014-09-25             16             4          6297
# 1996        1997 2014-09-26             17             3          9021
# ...

# %%
#cargar los datos en la base de datos
load_data(factura,'empresa','factura')
# Out:
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table factura

# %% [markdown]
# # Detalle Factura

# %%
#hacer la transformacion de los datos 
detalle_factura = data['DETALLE_FACTURA']
detalle_factura = drop_null(detalle_factura)
detalle_factura = uppercase(detalle_factura)
detalle_factura = remove_accents(detalle_factura)
detalle_factura
# Out:
# /Users/kcire/Library/CloudStorage/GoogleDrive-erickcarrillo2807@gmail.com/Mi unidad/Programacion/Python/Projects/Empresa/Code/transformacion.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: unidecode(str(x)) if isinstance(x, str) else x)
#       NUMEROFACT  CLAVEPROD  DETFACTCANTIDAD DETFACTPRODUNIDAD  DETFACTPRECIO  \
# 0              1          2               22             LITRO             64
# 1              1         20               70                KG             89
# 2              2         12               77             LITRO             26
# 3              2          4               79             LITRO             64
# 4              3         12               37             LITRO             26
# ...          ...        ...              ...               ...            ...
# 3995        1998         15               90                KG             77
# ...

# %%
#cargar los datos en la base de datos
print('test')
load_data(detalle_factura,'empresa','detalle_factura')
# Out:
# test
# Loading data into empresa...
# Database 'empresa' already exists.
# ✅ Connection established
# 📤 Data loaded successfully into table detalle_factura

# %% [markdown]
# # Consulta los datos en la base de datos
